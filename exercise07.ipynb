# %% [markdown]
# # Building agentic workflows from scratch
#
# As mentioned, `AgentWorkflow` is a pre-built `Workflow`, so you've already encountered many of the concepts you need to build a workflow from scratch.
#
# You can easily build your own workflows directly to create multi-agent systems that are customized to your needs. There's a number of reasons you might want to branch out from AgentWorkflow to rolling your own workflow:
#
# * 🎛️ **Fine-grained flow control**: Workflows allow looping, branching, parallel calls and map-reduce behavior. Workflows allow you to precisely specify how data gets passed around your system.
#
# * 🔁 **Structured inputs and outputs**: If you want your inputs and outputs to be richer than simple strings, or to kick off with more than just a `user_msg`, workflows allow you to do that.
#
# * 🎨 **Multimodality**: LlamaIndex can handle more than just text! You can handle images, audio and video as well.
#
# * 🧭 **Query planning**: a custom workflow can execute complex planning of how to run based on its inputs, rather than immediately jumping into a team.
#
# * 🔍 **Reflection**: A powerful technique for agents is their ability to examine their own output and decide whether it's sufficient, or if they need to try again. Using looping, you can implement this pattern.

# %% [markdown]
# ## ➡️ Creating a new workflow
#
# Under the hood, Workflows are regular Python classes. They are defined as a series of `steps`, each of which receives certain classes of events and emits certain classes of events.
#
# Here's the most basic form of a workflow, with a single step:

# %% [markdown]
# ### ❗️ Note: Run the **hidden cells** below before running the rest of the code. ❗️

# %%
# !pip install llama-index -q -q

# %%
# Fix: Install the llama-index package before importing
# !pip install llama-index

from llama_index.core.workflow import (
    StartEvent,
    StopEvent,
    Workflow,
    step,
)

class MyWorkflow(Workflow):
    @step
    async def my_step(self, ev: StartEvent) -> StopEvent:
        # Do something here
        return StopEvent(result="Hello, world!")
# Out:
# Requirement already satisfied: llama-index in /home/repl/.venv-user/lib/python3.12/site-packages (0.14.24)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.24 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index) (0.14.24)
# Requirement already satisfied: llama-index-embeddings-openai<0.7,>=0.6.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index) (0.6.0)
# Requirement already satisfied: llama-index-llms-openai<0.8,>=0.7.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index) (0.7.10)
# Requirement already satisfied: nltk>=3.9.3 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index) (3.10.3)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (3.12.15)
# Requirement already satisfied: aiosqlite in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (2.5.1)
# Requirement already satisfied: dataclasses-json in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (2025.3.0)
# Requirement already satisfied: httpx in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows<3,>=2.14.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (2.24.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (3.4.2)
# Requirement already satisfied: numpy in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (2.1.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (11.3.0)
# Requirement already satisfied: platformdirs in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (4.3.8)
# Requirement already satisfied: pydantic>=2.8.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (2.13.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (2.32.4)
# Requirement already satisfied: setuptools>=80.9.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /home/repl/.venv-user/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.24->llama-index) (2.0.38)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (0.9.0)
# Requirement already satisfied: tinytag>=2.2.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (2.3.2)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (4.16.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-core<0.15.0,>=0.14.24->llama-index) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/repl/.venv-user/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama-index) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/repl/.venv-user/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama-index) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama-index) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.24->llama-index) (1.20.1)
# Requirement already satisfied: griffe in /home/repl/.venv-user/lib/python3.12/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (2.3.0)
# Requirement already satisfied: jinja2 in /home/repl/.venv-user/lib/python3.12/site-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (3.1.6)
# Requirement already satisfied: openai>=1.1.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (2.54.0)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /home/repl/.venv-user/lib/python3.12/site-packages (from llama-index-workflows<3,>=2.14.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (0.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (0.17.0)
# Requirement already satisfied: sniffio in /home/repl/.venv-user/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /home/repl/.venv-user/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai<0.7,>=0.6.0->llama-index) (3.10)
# Requirement already satisfied: certifi in /home/repl/.venv-user/lib/python3.12/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.24->llama-index) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/repl/.venv-user/lib/python3.12/site-packages (from httpx->llama-index-core<0.15.0,>=0.14.24->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/repl/.venv-user/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.24->llama-index) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /home/repl/.venv-user/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/repl/.venv-user/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (0.4.4)
# Requirement already satisfied: defusedxml in /home/repl/.venv-user/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index) (0.7.1)
# Requirement already satisfied: click in /home/repl/.venv-user/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index) (8.2.1)
# Requirement already satisfied: joblib in /home/repl/.venv-user/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/repl/.venv-user/lib/python3.12/site-packages (from nltk>=3.9.3->llama-index) (2025.7.34)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/repl/.venv-user/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/repl/.venv-user/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (2.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/repl/.venv-user/lib/python3.12/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.24->llama-index) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.24->llama-index) (3.26.2)
# Requirement already satisfied: packaging>=17.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.15.0,>=0.14.24->llama-index) (25.0)
# Requirement already satisfied: griffecli==2.3.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (2.3.0)
# Requirement already satisfied: griffelib==2.3.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (2.3.0)
# Requirement already satisfied: colorama>=0.4 in /home/repl/.venv-user/lib/python3.12/site-packages (from griffecli==2.3.0->griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/repl/.venv-user/lib/python3.12/site-packages (from jinja2->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.24->llama-index) (3.0.2)
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# This new `MyWorkflow` class:
# * Uses the `@step` decorator to declare a function to be a step
# * Has a single step called `my_step` which accepts a `StartEvent`. `StartEvent` is a special event which is always generated when a workflow first runs.
# * `my_step` returns a `StopEvent`, which is another special event. When a `StopEvent` is emitted the workflow returns it and stops running.
#
# We instantiate it and run it just like you ran the `AgentWorkflow`:

# %%
workflow = MyWorkflow(timeout=10, verbose=False)
result = await workflow.run()
print(result)
# Out:
# Hello, world!

# %% [markdown]
# ## </> Aside: running a workflow in regular Python
#
# Workflows are async by default, so we use `await` to get the result of the `run` command. This will work fine in a notebook environment; if you are using a vanilla Python script, you will need to import `asyncio` and wrap your code in an async function, like this:
#
# ```
# async def main():
#     w = MyWorkflow(timeout=10, verbose=False)
#     result = await w.run()
#     print(result)
#
#
# if __name__ == "__main__":
#     import asyncio
#     asyncio.run(main())
# ```
#
# Since we're in a notebook right now, we won't execute the above code as it won't work!

# %% [markdown]
# ## 🖥 Visualizing a workflow
#
# A great feature of workflows is the built-in visualizer, which we will install now:

# %%
# !pip install llama-index-utils-workflow -q -q

# %% [markdown]
# Let's visualize the simple workflow we just created:

# %%
from llama_index.utils.workflow import draw_all_possible_flows

draw_all_possible_flows(MyWorkflow, filename="basic_workflow.html")
# Out:
# basic_workflow.html

# %% [markdown]
# This creates a file called `basic_workflow.html` in the notebook's file system. You can open up the file pane and download the file, then open it in your browser. You'll see something like this:

# %% [markdown]
# <img width="500" src="images/basic_flow.png">
